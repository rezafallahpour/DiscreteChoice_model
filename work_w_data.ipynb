# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('F:/more work/netherland/mnp2019/pnew.csv')
# Out:
# c:\Users\Reza\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3135: DtypeWarning: Columns (25,646,659,711,763,822,823,825,826,827,828) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df['PERSID'].sort_values()
# Out:
# 0        3000071501
# 1        3000071501
# 2        3000071501
# 3        3000071501
# 4        3000071501
#             ...
# 57447    7000016602
# 57445    7000016602
# 57455    7000016602
# 57449    7000016602
# 57456    7000016602
# Name: PERSID, Length: 57457, dtype: int64

# %%
p=df.dropna(subset=['HVM','RVM'])

# %%
p
# Out:
#           ID      HHID                                         HH_VALID_x  \
# 0          0  30000715  complete household, all persons questionnaire ...
# 1          1  30000715  complete household, all persons questionnaire ...
# 2          2  30000715  complete household, all persons questionnaire ...
# 3          3  30000715  complete household, all persons questionnaire ...
# 4          4  30000715  complete household, all persons questionnaire ...
# ...      ...       ...                                                ...
# 57452  57452  70000166  complete household, all persons questionnaire ...
# 57453  57453  70000166  complete household, all persons questionnaire ...
# 57454  57454  70000166  complete household, all persons questionnaire ...
# 57455  57455  70000166  complete household, all persons questionnaire ...
# 57456  57456  70000166  complete household, all persons questionnaire ...
#
#        DEELNAME                           IMPHHDATA_x  \
# ...

# %%
f=p.copy()

# %%
f
# Out:
#           ID      HHID                                         HH_VALID_x  \
# 0          0  30000715  complete household, all persons questionnaire ...
# 1          1  30000715  complete household, all persons questionnaire ...
# 2          2  30000715  complete household, all persons questionnaire ...
# 3          3  30000715  complete household, all persons questionnaire ...
# 4          4  30000715  complete household, all persons questionnaire ...
# ...      ...       ...                                                ...
# 57452  57452  70000166  complete household, all persons questionnaire ...
# 57453  57453  70000166  complete household, all persons questionnaire ...
# 57454  57454  70000166  complete household, all persons questionnaire ...
# 57455  57455  70000166  complete household, all persons questionnaire ...
# 57456  57456  70000166  complete household, all persons questionnaire ...
#
#        DEELNAME                           IMPHHDATA_x  \
# ...

# %%
f=f.loc[f['AANTRIT'] != 'On this day the person did not take a trip']

# %%
f['Multimodal']=np.where(f['AANTRIT']!='1',1,0)
# Out:
# C:\Users\Reza\AppData\Local\Temp\ipykernel_17124\903600162.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f['Multimodal']=np.where(f['AANTRIT']!='1',1,0)

# %%
f['Multimodal'].value_counts()
# Out:
# 0    43773
# 1     9537
# Name: Multimodal, dtype: int64

# %%
f.to_csv('F:/more work/netherland/mnp2019/python/first.csv')
